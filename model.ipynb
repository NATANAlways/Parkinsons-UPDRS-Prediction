# %% [markdown]
# **Name: S.Nathiskar**

# %% [markdown]
# A Health And Medicine Dataset: **Parkinson’s Telemonitoring Data**

# %% [markdown]
# **Link of the dataset:** https://archive.ics.uci.edu/dataset/189/parkinsons+telemonitoring

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Dataset Description:**
#
#   This is Parkinson’s Telemonitoring Data
#   ,the dataset contains 5,875 samples and 22 features, representing clinical and voice measurements of patients with Parkinson’s disease.

# %% [markdown]
# a. The Features are:
#
#     age, sex, test_time, Jitter(%), Jitter(Abs), Jitter:RAP, Jitter:PPQ5, Jitter:DDP, Shimmer, Shimmer(dB), Shimmer:APQ3, Shimmer:APQ5, Shimmer:APQ11, Shimmer:DDA, NHR, HNR, RPDE, DFA, PPE, motor_UPDRS, total_UPDRS

# %% [markdown]
# The dataset includes the following independent variables (features):
#
# - **subject#** – Unique identifier for each patient.
# - **age** – Age of the patient.
# - **sex** – Gender (0 = Male, 1 = Female).
# - **test_time** – Elapsed time since the baseline test.
# - **Jitter(%)** – Measure of frequency variation in voice.
# - **Jitter(Abs)** – Absolute measure of frequency perturbation.
# - **Jitter:RAP** – Relative average perturbation.
# - **Jitter:PPQ5** – Five-point period perturbation quotient.
# - **Jitter:DDP** – Average absolute difference of differences between consecutive periods.
# - **Shimmer** – Amplitude variation in voice signal.
# - **Shimmer(dB)** – Shimmer value measured in decibels.
# - **Shimmer:APQ3** – Three-point amplitude perturbation quotient.
# - **Shimmer:APQ5** – Five-point amplitude perturbation quotient.
# - **Shimmer:APQ11** – Eleven-point amplitude perturbation quotient.
# - **Shimmer:DDA** – Average absolute difference of differences between consecutive amplitudes.
# - **NHR** – Noise-to-Harmonics Ratio (higher values indicate more noise in the voice).
# - **HNR** – Harmonics-to-Noise Ratio (higher values indicate a clearer voice signal).
# - **RPDE** – Recurrence period density entropy (used to measure signal complexity).
# - **DFA** – Detrended fluctuation analysis (used for long-range correlation measurement).
# - **PPE** – Pitch period entropy (measures voice signal stability).

# %% [markdown]
# **b.Target Values:**
#
#
# The dataset has two target values (dependent variables):
#
# - **motor_UPDRS** – Unified Parkinson’s Disease Rating Scale (UPDRS) score for motor function.
# - **total_UPDRS** – Overall UPDRS score, including motor and non-motor symptoms.
#
# But here I am using total_UPDRS, to predict

# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset
file_path = "/content/parkinsons_updrs.data.csv"
df = pd.read_csv(file_path)
# see first 5 dataframe
df.head()
# Out:
#    subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0         1   72    0     5.6431       28.199       34.398    0.00662
# 1         1   72    0    12.6660       28.447       34.894    0.00300
# 2         1   72    0    19.6810       28.695       35.389    0.00481
# 3         1   72    0    25.6470       28.905       35.810    0.00528
# 4         1   72    0    33.6420       29.187       36.375    0.00335
#
#    Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  Shimmer:APQ3  \
# 0     0.000034     0.00401      0.00317  ...        0.230       0.01438
# 1     0.000017     0.00132      0.00150  ...        0.179       0.00994
# 2     0.000025     0.00205      0.00208  ...        0.181       0.00734
# 3     0.000027     0.00191      0.00264  ...        0.327       0.01106
# 4     0.000020     0.00093      0.00130  ...        0.176       0.00679
#
#    Shimmer:APQ5  Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE  \
# ...

# %%
# Display basic information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5875 entries, 0 to 5874
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   subject#       5875 non-null   int64
#  1   age            5875 non-null   int64
#  2   sex            5875 non-null   int64
#  3   test_time      5875 non-null   float64
#  4   motor_UPDRS    5875 non-null   float64
#  5   total_UPDRS    5875 non-null   float64
#  6   Jitter(%)      5875 non-null   float64
#  7   Jitter(Abs)    5875 non-null   float64
#  8   Jitter:RAP     5875 non-null   float64
#  9   Jitter:PPQ5    5875 non-null   float64
#  10  Jitter:DDP     5875 non-null   float64
#  11  Shimmer        5875 non-null   float64
#  12  Shimmer(dB)    5875 non-null   float64
#  13  Shimmer:APQ3   5875 non-null   float64
#  14  Shimmer:APQ5   5875 non-null   float64
#  15  Shimmer:APQ11  5875 non-null   float64
#  16  Shimmer:DDA    5875 non-null   float64
# ...

# %% [markdown]
# **c. Samples**
#
# - **Total records:** 5,875
# - **Patients:** Multiple patients, identified by subject#.
# - **Data type:**Either integers or floating-point values.
# - **Use case:** The dataset is primarily used for predicting UPDRS scores based on voice and clinical features.
#
#
#
#     subject#           : int64
#
#
#     age                : int64
#
#
#     sex                : int64
#
#
#     test_time          : float64
#
#
#     motor_UPDRS        : float64
#
#
#     total_UPDRS        : float64
#
#
#     Jitter(%)          : float64
#
#
#     Jitter(Abs)        : float64
#
#
#     Jitter:RAP         : float64
#
#
#     Jitter:PPQ5        : float64
#
#
#     Jitter:DDP         : float64
#
#
#     Shimmer            : float64
#
#
#     Shimmer:DDA        : float64
#
#
#     Shimmer:APQ11      : float64
#
#
#     Shimmer:APQ5       : float64
#
#
#     Shimmer:APQ3       : float64
#
#
#     Shimmer(dB)        : float64
#
#
#     NHR                : float64
#
#
#     HNR                : float64
#
#
#     RPDE               : float64
#
#
#     DFA                : float64
#
#
#     PPE                : float64
#
#
#
# **No Missing values**

# %%
df.isnull().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %% [markdown]
# **Sample Description on Basis of Statictical values**

# %%
# getting statistical values
df.describe()
# Out:
#           subject#          age          sex    test_time  motor_UPDRS  \
# count  5875.000000  5875.000000  5875.000000  5875.000000  5875.000000
# mean     21.494128    64.804936     0.317787    92.863722    21.296229
# std      12.372279     8.821524     0.465656    53.445602     8.129282
# min       1.000000    36.000000     0.000000    -4.262500     5.037700
# 25%      10.000000    58.000000     0.000000    46.847500    15.000000
# 50%      22.000000    65.000000     0.000000    91.523000    20.871000
# 75%      33.000000    72.000000     1.000000   138.445000    27.596500
# max      42.000000    85.000000     1.000000   215.490000    39.511000
#
#        total_UPDRS    Jitter(%)  Jitter(Abs)   Jitter:RAP  Jitter:PPQ5  ...  \
# count  5875.000000  5875.000000  5875.000000  5875.000000  5875.000000  ...
# mean     29.018942     0.006154     0.000044     0.002987     0.003277  ...
# std      10.700283     0.005624     0.000036     0.003124     0.003732  ...
# ...

# %%
# checking for duplicate data entry
df.duplicated().sum()
# Out:
# 0

# %%
# List all column names
columns = df.columns.tolist()
print("All Columns:", columns)
# Out:
# All Columns: ['subject#', 'age', 'sex', 'test_time', 'motor_UPDRS', 'total_UPDRS', 'Jitter(%)', 'Jitter(Abs)', 'Jitter:RAP', 'Jitter:PPQ5', 'Jitter:DDP', 'Shimmer', 'Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5', 'Shimmer:APQ11', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA', 'PPE']

# %% [markdown]
# **Separating target values and features**

# %%
# the y value (dependent values)
y = df[['total_UPDRS']]
y.shape
# Out:
# (5875, 1)

# %%
# the x values: independent values
x = df.drop(['total_UPDRS', 'motor_UPDRS', 'subject#'], axis=1)
x.shape
# Out:
# (5875, 19)

# %%
# information of y values
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5875 entries, 0 to 5874
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   total_UPDRS  5875 non-null   float64
# dtypes: float64(1)
# memory usage: 46.0 KB

# %%
# information of x values
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5875 entries, 0 to 5874
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            5875 non-null   int64
#  1   sex            5875 non-null   int64
#  2   test_time      5875 non-null   float64
#  3   Jitter(%)      5875 non-null   float64
#  4   Jitter(Abs)    5875 non-null   float64
#  5   Jitter:RAP     5875 non-null   float64
#  6   Jitter:PPQ5    5875 non-null   float64
#  7   Jitter:DDP     5875 non-null   float64
#  8   Shimmer        5875 non-null   float64
#  9   Shimmer(dB)    5875 non-null   float64
#  10  Shimmer:APQ3   5875 non-null   float64
#  11  Shimmer:APQ5   5875 non-null   float64
#  12  Shimmer:APQ11  5875 non-null   float64
#  13  Shimmer:DDA    5875 non-null   float64
#  14  NHR            5875 non-null   float64
#  15  HNR            5875 non-null   float64
#  16  RPDE           5875 non-null   float64
# ...

# %%
# splitting the dataset as train and test values
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
# Displaying the test and train dataset
print("x_train: ", x_train.shape)
print("x_test: ", x_test.shape)
print("y_train: ", y_train.shape)
print("y_test: ", y_test.shape)
# Out:
# x_train:  (4700, 19)
# x_test:  (1175, 19)
# y_train:  (4700, 1)
# y_test:  (1175, 1)

# %%
x_train.head()
# Out:
#       age  sex  test_time  Jitter(%)  Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  \
# 598    75    0     56.428    0.00493     0.000041     0.00214      0.00278
# 4511   66    1     30.401    0.00330     0.000010     0.00158      0.00153
# 5284   66    0     61.510    0.02251     0.000219     0.01262      0.00902
# 1431   58    0     52.356    0.01150     0.000105     0.00462      0.00581
# 3582   49    0    161.870    0.00603     0.000045     0.00309      0.00307
#
#       Jitter:DDP  Shimmer  Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  \
# 598      0.00643  0.04291        0.368       0.02268       0.02892
# 4511     0.00475  0.02274        0.229       0.01200       0.01291
# 5284     0.03785  0.05579        0.538       0.02656       0.03037
# 1431     0.01387  0.03020        0.404       0.01567       0.01755
# 3582     0.00928  0.10820        0.936       0.06262       0.06365
#
#       Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE      DFA      PPE
# ...

# %% [markdown]
# **Linear Regression**

# %%
# import linear regression model
from sklearn.linear_model import LinearRegression
# import evaluating the model
from sklearn.metrics import mean_squared_error, r2_score

# Create a linear regression model
model = LinearRegression()

# %%
# train the model
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# make prediction using the test data
y_pred_LR = model.predict(x_test)

# %%
y_pred_LR
# Out:
# array([[27.98769038],
#        [34.51557512],
#        [25.78787418],
#        ...,
#        [33.39139723],
#        [30.78122487],
#        [26.28918089]])

# %%
# the linear Regression model coeffieceint and intercept
print(f"Coefficient: {model.coef_}")
print(f"Intercept: {model.intercept_}")
# Out:
# Coefficient: [[ 3.06646630e-01 -2.73140279e+00  1.88334148e-02  6.45161310e+01
#   -6.24421510e+04 -7.87809463e+04 -4.05474945e+02  2.65531380e+04
#    1.36460400e+02 -7.38622353e+00 -7.15843801e+03 -3.73817947e+01
#    5.44396700e+01  2.30402379e+03 -1.78632020e+01 -6.20837841e-01
#    4.90797930e+00 -3.27128336e+01  1.78708517e+01]]
# Intercept: [39.25018725]

# %%
# model evaluation
# Mean Square Error
mse_LR = mean_squared_error(y_test, y_pred_LR)
# R - squared value
r2_LR = r2_score(y_test, y_pred_LR)

# %%
# Displaying the evaluation results
print(f"Mean Squared Error: {mse_LR}")
print(f"Root Mean Squared Error: {np.sqrt(mse_LR)}")
print(f"R-squared: {r2_LR}")
# Out:
# Mean Squared Error: 94.99714500065588
# Root Mean Squared Error: 9.746647885332468
# R-squared: 0.14773361788283335

# %% [markdown]
# **Random Forest Regression**

# %%
# for model building the Random Forest model
from sklearn.ensemble import RandomForestRegressor

# %%
# Initializing the Random Forest Regression model
model = RandomForestRegressor(n_estimators=100,random_state=42)
# train
model.fit(x_train,y_train)
# predict
y_pred_RF = model.predict(x_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
# model evaluation
# Mean Square Error
mse_RF = mean_squared_error(y_test, y_pred_RF)
# R - squared value
r2_RF = r2_score(y_test, y_pred_RF)

# %%
# Displaying the evaluation results
print(f"Mean Squared Error: {mse_RF}")
print(f"Root Mean Squared Error: {np.sqrt(mse_RF)}")
print(f"R-squared: {r2_RF}")
# Out:
# Mean Squared Error: 3.924245840586413
# Root Mean Squared Error: 1.9809709338065546
# R-squared: 0.9647936492715457

# %% [markdown]
# **Support Vector Regression**

# %%
# import support vector regression model
from sklearn.svm import SVR
# for scaling
from sklearn.preprocessing import StandardScaler

# %%
# SVR model
model = SVR(kernel = "rbf")
# train the model
model.fit(x_train, y_train)
# make prediction on the test data
y_pred_SVR = model.predict(x_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# model evaluation
# Mean Square Error
mse_SVR = mean_squared_error(y_test, y_pred_SVR)
# R - squared value
r2_SVR = r2_score(y_test, y_pred_SVR)

# %%
# Displaying the evaluation results
print(f"Mean Squared Error: {mse_SVR}")
print(f"Root Mean Squared Error: {np.sqrt(mse_SVR)}")
print(f"R-squared: {r2_SVR}")
# Out:
# Mean Squared Error: 103.85125070810565
# Root Mean Squared Error: 10.190743383488059
# R-squared: 0.06829905552710047

# %% [markdown]
# ### Performance Comparison of Models
#
# ### Linear Regression Model Evaluation
#
# - **Mean Squared Error (MSE)**: 94.99
# - **Root Mean Squared Error (RMSE)**: 9.75
# - **R-squared (R²)**: 0.1477
#
#
# ### Random Forest Regression Model Evaluation
#
# - **Mean Squared Error (MSE)**: 3.92
# - **Root Mean Squared Error (RMSE)**: 1.98
# - **R-squared (R²)**: 0.9648
#
# ### SVR Model Evaluation
#
# - **Mean Squared Error (MSE)**: 103.85
# - **Root Mean Squared Error (RMSE)**: 10.19
# - **R-squared (R²)**: 0.0683
#
#
# The performance comparison of these three models reveals that **Random Forest Regression** outperforms **SVR** and **Linear Regression** with the lowest **MSE** and **RMSE** values and a higher **R²**.
#
# - **SVR** has high error values and a low **R²**, which indicates a poor model fit.
# - **Linear Regression** performs a little better than **SVR**, but still underperforms when compared to the **Random Forest Regression** model.
#
#
#
# In conclusion, the **Random Forest Regression** model is the best fit for this dataset among the regression models used here.
